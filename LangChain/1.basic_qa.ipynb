# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
# Set your key
load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')

# %%
# Initialize the model (Gemini 1.5 Flash is the fastest free one)
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# Use it just like you would use Claude
#response = model.invoke('What is the difference between a chain and an agent in LangChain?')
response = model.invoke('Who is the present minister of Abuja?')
print(response.content)
# Out:
# The present Minister of the Federal Capital Territory (FCT), Abuja, is **Nyesom Wike**.
#
# He was appointed by President Bola Ahmed Tinubu and sworn into office on August 21, 2023.
